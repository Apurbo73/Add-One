# %% [markdown]
# <a href="https://colab.research.google.com/github/Apurbo73/Add-One/blob/master/Conditional_Logics_in_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= 50
b= 80
if a>b:
  print ("a is greater than b")
else:
    print ("b is greater than a")
if b%2==0:
    print ("b is divisible by 2")
# Out:
# b is greater than a
# b is divisible by 2
